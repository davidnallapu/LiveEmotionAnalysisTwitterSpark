# %%
import pandas as pd
import numpy as np
import os
os.environ["JAVA_HOME"] = "/Library/Java/JavaVirtualMachines/adoptopenjdk-8.jdk/Contents/Home"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
import json
from pyspark.ml import Pipeline
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from sparknlp.annotator import *
from sparknlp.base import *
import sparknlp
from sparknlp.pretrained import PretrainedPipeline
import collections
import matplotlib.pyplot as plt

# %%
spark = sparknlp.start()

# %%
MODEL_NAME='classifierdl_use_emotion'

# %%
documentAssembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")
    
use = UniversalSentenceEncoder.pretrained(name="tfhub_use", lang="en")\
 .setInputCols(["document"])\
 .setOutputCol("sentence_embeddings")


sentimentdl = ClassifierDLModel.pretrained(name=MODEL_NAME)\
    .setInputCols(["sentence_embeddings"])\
    .setOutputCol("sentiment")

nlpPipeline = Pipeline(
      stages = [
          documentAssembler,
          use,
          sentimentdl
      ])
# Out:
# tfhub_use download started this may take some time.
# Approximate size to download 923.7 MB
# [OK!]
# classifierdl_use_emotion download started this may take some time.
# Approximate size to download 21.3 MB
# [OK!]

# %%
def predict_emotion(text_list):
    empty_df = spark.createDataFrame([['']]).toDF("text")
    pipelineModel = nlpPipeline.fit(empty_df)
    df = spark.createDataFrame(pd.DataFrame({"text":text_list}))
    result = pipelineModel.transform(df)
#     result.select(F.explode(F.arrays_zip('document.result', 'sentiment.result')).alias("cols")) \
#     .select(F.expr("cols['0']").alias("document"),
#         F.expr("cols['1']").alias("sentiment")).show(truncate=False)
    #Getting a list of emotions
    emotions = []
    for i in result.select(F.collect_list('sentiment')).first()[0]:
        emotions.append(str(i[0].result))

    #Getting a count of the emotions
    
    counter=collections.Counter(emotions)
    print(counter)
    #Creating a dataframe from counter 
#     df = pd.DataFrame.from_dict(counter, orient='index').reset_index()
    
#     #Visualisation
#     labels, values = zip(*counter.items())

#     indexes = np.arange(len(labels))
#     width = 1
#     import matplotlib.pyplot as plt
#     plt.bar(indexes, values, width)
#     plt.xticks(indexes + width * 0.5, labels)
#     if(len(text_list)%10==0):
#         plt.show()
    fig= plt.figure()
    ax = plt.gca()
    def animate_frame(i):
        labels, values = zip(*counter.items())
        indexes = np.arange(len(labels))
        width = 1
        plt.bar(indexes, values, width)
        plt.xticks(indexes + width * 0.5, labels)

    animation = FuncAnimation(fig, func=animate_frame, interval=1000)
    plt.show()

# %%
import time
import os
import re

text_list = []
def follow(thefile):
    '''generator function that yields new lines in a file
    '''
    # seek the end of the file
    thefile.seek(0, os.SEEK_END)
    
    # start infinite loop
    while True:
        # read last line of file
        line = thefile.readline()
        # sleep if file hasn't been updated
        if not line:
            time.sleep(0.1)
            continue
        yield line

if __name__ == '__main__':
    logfile = open("tweets.txt","r")
    loglines = follow(logfile)
    # iterate over the generator
    for s in loglines:
        re.sub("\S*\d\S*", "", s).strip()
        tokens = s.strip().split()
        clean_tokens = [t for t in tokens if re.match(r'[^\W\d]*$', t)]
        clean_s = ' '.join(clean_tokens)
        if(len(clean_s.split(' '))>1):
            text_list.append(clean_s)
            predict_emotion(text_list)
# Out:
# Counter({'fear': 1})
# Counter({'fear': 1, 'surprise': 1})
# Counter({'surprise': 2, 'fear': 1})
# Counter({'surprise': 3, 'fear': 1})
# Counter({'surprise': 4, 'fear': 1})
# Counter({'surprise': 5, 'fear': 1})
# Counter({'surprise': 5, 'fear': 2})
# Counter({'surprise': 5, 'fear': 3})
# Counter({'surprise': 6, 'fear': 3})
# Counter({'surprise': 7, 'fear': 3})
# Counter({'surprise': 8, 'fear': 3})
# Counter({'surprise': 8, 'fear': 4})
# Counter({'surprise': 8, 'fear': 5})
# Counter({'surprise': 8, 'fear': 6})
# Counter({'surprise': 8, 'fear': 6, 'sadness': 1})
# Counter({'surprise': 8, 'fear': 7, 'sadness': 1})
# Counter({'fear': 8, 'surprise': 8, 'sadness': 1})
# Counter({'fear': 9, 'surprise': 8, 'sadness': 1})
# Counter({'fear': 9, 'surprise': 9, 'sadness': 1})
# Counter({'fear': 10, 'surprise': 9, 'sadness': 1})
# Counter({'fear': 11, 'surprise': 9, 'sadness': 1})
# Counter({'fear': 11, 'surprise': 10, 'sadness': 1})
# Counter({'fear': 12, 'surprise': 10, 'sadness': 1})
# Counter({'fear': 12, 'surprise': 11, 'sadness': 1})
# Counter({'fear': 12, 'surprise': 12, 'sadness': 1})
# Counter({'surprise': 13, 'fear': 12, 'sadness': 1})
# Counter({'fear': 13, 'surprise': 13, 'sadness': 1})
# Counter({'surprise': 14, 'fear': 13, 'sadness': 1})
# Counter({'fear': 14, 'surprise': 14, 'sadness': 1})
# Counter({'surprise': 15, 'fear': 14, 'sadness': 1})
# Counter({'surprise': 16, 'fear': 14, 'sadness': 1})
# Counter({'surprise': 17, 'fear': 14, 'sadness': 1})
# Counter({'surprise': 17, 'fear': 14, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 17, 'fear': 15, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 17, 'fear': 16, 'sadness': 1, 'joy': 1})
# Counter({'fear': 17, 'surprise': 17, 'sadness': 1, 'joy': 1})
# Counter({'fear': 18, 'surprise': 17, 'sadness': 1, 'joy': 1})
# Counter({'fear': 18, 'surprise': 18, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 19, 'fear': 18, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 20, 'fear': 18, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 21, 'fear': 18, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 22, 'fear': 18, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 22, 'fear': 19, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 22, 'fear': 20, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 23, 'fear': 20, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 24, 'fear': 20, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 25, 'fear': 20, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 25, 'fear': 21, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 25, 'fear': 22, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 26, 'fear': 22, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 26, 'fear': 23, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 27, 'fear': 23, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 28, 'fear': 23, 'sadness': 1, 'joy': 1})
# Counter({'surprise': 28, 'fear': 23, 'joy': 2, 'sadness': 1})
# Counter({'surprise': 28, 'fear': 24, 'joy': 2, 'sadness': 1})
# Counter({'surprise': 28, 'fear': 24, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 29, 'fear': 24, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 30, 'fear': 24, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 31, 'fear': 24, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 32, 'fear': 24, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 32, 'fear': 25, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 32, 'fear': 26, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 33, 'fear': 26, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 33, 'fear': 27, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 34, 'fear': 27, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 34, 'fear': 28, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 34, 'fear': 29, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 34, 'fear': 30, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 34, 'fear': 31, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 34, 'fear': 32, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 35, 'fear': 32, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 35, 'fear': 33, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 35, 'fear': 34, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 36, 'fear': 34, 'sadness': 2, 'joy': 2})
# Counter({'surprise': 37, 'fear': 34, 'sadness': 2, 'joy': 2})
# Counter({'surprise':
 'joy': 22, 'sadness': 20})
# Counter({'surprise': 281, 'fear': 271, 'joy': 22, 'sadness': 20})
# Counter({'surprise': 282, 'fear': 271, 'joy': 22, 'sadness': 20})
# Counter({'surprise': 282, 'fear': 272, 'joy': 22, 'sadness': 20})
# Counter({'surprise': 283, 'fear': 272, 'joy': 22, 'sadness': 20})
# Counter({'surprise': 283, 'fear': 273, 'joy': 22, 'sadness': 20})
# Counter({'surprise': 284, 'fear': 273, 'joy': 22, 'sadness': 20})
# Counter({'surprise': 284, 'fear': 274, 'joy': 22, 'sadness': 20})
# Counter({'surprise': 284, 'fear': 275, 'joy': 22, 'sadness': 20})
# Counter({'surprise': 284, 'fear': 276, 'joy': 22, 'sadness': 20})
# Counter({'surprise': 285, 'fear': 276, 'joy': 22, 'sadness': 20})
# Counter({'surprise': 285, 'fear': 277, 'joy': 22, 'sadness': 20})
# Counter({'surprise': 285, 'fear': 278, 'joy': 22, 'sadness': 20})
# Counter({'surprise': 285, 'fear': 278, 'joy': 22, 'sadness': 21})
# Counter({'surprise': 286, 'fear': 278, 'joy': 22, 'sadness': 21})
# Counter({'surprise': 286, 'fear': 279, 'joy': 22, 'sadness': 21})
# Counter({'surprise': 287, 'fear': 279, 'joy': 22, 'sadness': 21})
# Counter({'surprise': 287, 'fear': 280, 'joy': 22, 'sadness': 21})
# Counter({'surprise': 287, 'fear': 281, 'joy': 22, 'sadness': 21})
# Counter({'surprise': 287, 'fear': 282, 'joy': 22, 'sadness': 21})
# Counter({'surprise': 287, 'fear': 282, 'joy': 23, 'sadness': 21})
# Counter({'surprise': 287, 'fear': 283, 'joy': 23, 'sadness': 21})
# Counter({'surprise': 288, 'fear': 283, 'joy': 23, 'sadness': 21})
# Counter({'surprise': 289, 'fear': 283, 'joy': 23, 'sadness': 21})
# Counter({'surprise': 290, 'fear': 283, 'joy': 23, 'sadness': 21})
# Counter({'surprise': 290, 'fear': 283, 'joy': 24, 'sadness': 21})
# Counter({'surprise': 290, 'fear': 283, 'joy': 24, 'sadness': 22})
# Counter({'surprise': 291, 'fear': 283, 'joy': 24, 'sadness': 22})
# Counter({'surprise': 291, 'fear': 284, 'joy': 24, 'sadness': 22})
# Counter({'surprise': 291, 'fear': 285, 'joy': 24, 'sadness': 22})
# Counter({'surprise': 291, 'fear': 286, 'joy': 24, 'sadness': 22})
# Counter({'surprise': 291, 'fear': 287, 'joy': 24, 'sadness': 22})
# Counter({'surprise': 291, 'fear': 287, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 292, 'fear': 287, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 292, 'fear': 288, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 293, 'fear': 288, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 293, 'fear': 289, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 293, 'fear': 290, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 293, 'fear': 291, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 293, 'fear': 292, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 294, 'fear': 292, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 294, 'fear': 293, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 295, 'fear': 293, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 295, 'fear': 294, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 296, 'fear': 294, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 296, 'fear': 295, 'joy': 24, 'sadness': 23})
# Counter({'fear': 296, 'surprise': 296, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 297, 'fear': 296, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 298, 'fear': 296, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 299, 'fear': 296, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 299, 'fear': 297, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 299, 'fear': 298, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 300, 'fear': 298, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 301, 'fear': 298, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 301, 'fear': 299, 'joy': 24, 'sadness': 23})
# Counter({'surprise': 301, 'fear': 299, 'sadness': 24, 'joy': 24})
# Counter({'surprise': 301, 'fear': 300, 'sadness': 24, 'joy': 24})
# Counter({'surprise': 302, 'fear': 300, 'sadness': 24, 'joy': 24})
# Counter({'surprise': 302, 'fear': 301, 'sadness': 24, 'joy': 24})
# Counter({'fear': 302, 'surprise': 302, 'sadness': 24, 'joy': 24})
# Counter({'fear': 303, 'surprise': 302, 'sadness': 24, 'joy': 24})
# Counter({'fear': 303, 'surprise': 303, 'sadness': 24, 'joy': 24})
# Counter({'surprise': 304, 'fear': 303, 'sadness': 24, 'joy': 24})
# Counter({'fear': 304, 'surprise': 304, 'sadness': 24, 'joy': 24})
# Counter({'surprise': 305, 'fear': 304, 'sadness': 24, 'joy': 24})
# Counter({'surprise': 306, 'fear': 304, 'sadness': 24, 'joy': 24})
# Counter({'surprise': 307, 'fear': 304, 'sadness': 24, 'joy': 24})
# Counter({'surprise': 307, 'fear': 304, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 308, 'fear': 304, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 308, 'fear': 305, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 309, 'fear': 305, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 310, 'fear': 305, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 311, 'fear': 305, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 312, 'fear': 305, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 312, 'fear': 306, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 312, 'fear': 307, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 312, 'fear': 308, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 312, 'fear': 309, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 312, 'fear': 310, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 313, 'fear': 310, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 314, 'fear': 310, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 314, 'fear': 311, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 315, 'fear': 311, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 315, 'fear': 312, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 316, 'fear': 312, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 316, 'fear': 313, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 316, 'fear': 314, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 316, 'fear': 315, 'joy': 25, 'sadness': 24})
# Counter({'fear': 316, 'surprise': 316, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 317, 'fear': 316, 'joy': 25, 'sadness': 24})
# Counter({'fear': 317, 'surprise': 317, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 318, 'fear': 317, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 319, 'fear': 317, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 319, 'fear': 318, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 320, 'fear': 318, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 321, 'fear': 318, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 322, 'fear': 318, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 322, 'fear': 319, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 323, 'fear': 319, 'joy': 25, 'sadness': 24})
# Counter({'surprise': 323, 'fear': 319, 'joy': 26, 'sadness': 24})
# Counter({'surprise': 324, 'fear': 319, 'joy': 26, 'sadness': 24})
# Counter({'surprise': 325, 'fear': 319, 'joy': 26, 'sadness': 24})
# Counter({'surprise': 326, 'fear': 319, 'joy': 26, 'sadness': 24})
# Counter({'surprise': 326, 'fear': 319, 'joy': 26, 'sadness': 25})
# Counter({'surprise': 326, 'fear': 320, 'joy': 26, 'sadness': 25})
# Counter({'surprise': 327, 'fear': 320, 'joy': 26, 'sadness': 25})
# Counter({'surprise': 327, 'fear': 320, 'sadness': 26, 'joy': 26})
# Counter({'surprise': 328, 'fear': 320, 'sadness': 26, 'joy': 26})
# Counter({'surprise': 328, 'fear': 321, 'sadness': 26, 'joy': 26})
# Counter({'surprise': 329, 'fear': 321, 'sadness': 26, 'joy': 26})
# Counter({'surprise': 330, 'fear': 321, 'sadness': 26, 'joy': 26})
# Counter({'surprise': 330, 'fear': 322, 'sadness': 26, 'joy': 26})
# Counter({'surprise': 330, 'fear': 322, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 330, 'fear': 323, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 331, 'fear': 323, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 332, 'fear': 323, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 332, 'fear': 324, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 333, 'fear': 324, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 333, 'fear': 325, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 334, 'fear': 325, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 335, 'fear': 325, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 336, 'fear': 325, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 336, 'fear': 326, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 336, 'fear': 327, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 336, 'fear': 328, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 337, 'fear': 328, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 337, 'fear': 329, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 338, 'fear': 329, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 338, 'fear': 330, 'sadness': 27, 'joy': 26})
# Counter({'surprise': 338, 'fear': 330, 'sadness': 27, 'joy': 27})
# Counter({'surprise': 338, 'fear': 331, 'sadness': 27, 'joy': 27})
# Counter({'surprise': 338, 'fear': 332, 'sadness': 27, 'joy': 27})
# Counter({'surprise': 338, 'fear': 333, 'sadness': 27, 'joy': 27})
# Counter({'surprise': 338, 'fear': 334, 'sadness': 27, 'joy': 27})
# Counter({'surprise': 338, 'fear': 335, 'sadness': 27, 'joy': 27})
# Counter({'surprise': 339, 'fear': 335, 'sadness': 27, 'joy': 27})
# Counter({'surprise': 339, 'fear': 335, 'joy': 28, 'sadness': 27})
# Counter({'surprise': 339, 'fear': 336, 'joy': 28, 'sadness': 27})
# Counter({'surprise': 340, 'fear': 336, 'joy': 28, 'sadness': 27})
# Counter({'surprise': 340, 'fear': 337, 'joy': 28, 'sadness': 27})
# Counter({'surprise': 340, 'fear': 338, 'joy': 28, 'sadness': 27})
# Counter({'surprise': 340, 'fear': 338, 'sadness': 28, 'joy': 28})
# Counter({'surprise': 340, 'fear': 339, 'sadness': 28, 'joy': 28})
# Counter({'surprise': 341, 'fear': 339, 'sadness': 28, 'joy': 28})
# Counter({'surprise': 341, 'fear': 340, 'sadness': 28, 'joy': 28})
# Counter({'surprise': 342, 'fear': 340, 'sadness': 28, 'joy': 28})
# Counter({'surprise': 342, 'fear': 341, 'sadness': 28, 'joy': 28})
# Counter({'fear': 342, 'surprise': 342, 'sadness': 28, 'joy': 28})
# Counter({'fear': 342, 'surprise': 342, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 343, 'fear': 342, 'joy': 29, 'sadness': 28})
# Counter({'fear': 343, 'surprise': 343, 'joy': 29, 'sadness': 28})
# Counter({'fear': 344, 'surprise': 343, 'joy': 29, 'sadness': 28})
# Counter({'fear': 345, 'surprise': 343, 'joy': 29, 'sadness': 28})
# Counter({'fear': 345, 'surprise': 344, 'joy': 29, 'sadness': 28})
# Counter({'fear': 346, 'surprise': 344, 'joy': 29, 'sadness': 28})
# Counter({'fear': 346, 'surprise': 345, 'joy': 29, 'sadness': 28})
# Counter({'fear': 347, 'surprise': 345, 'joy': 29, 'sadness': 28})
# Counter({'fear': 347, 'surprise': 346, 'joy': 29, 'sadness': 28})
# Counter({'fear': 347, 'surprise': 347, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 348, 'fear': 347, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 349, 'fear': 347, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 350, 'fear': 347, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 351, 'fear': 347, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 351, 'fear': 348, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 352, 'fear': 348, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 353, 'fear': 348, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 353, 'fear': 349, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 354, 'fear': 349, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 355, 'fear': 349, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 356, 'fear': 349, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 356, 'fear': 350, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 357, 'fear': 350, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 357, 'fear': 351, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 358, 'fear': 351, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 359, 'fear': 351, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 360, 'fear': 351, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 361, 'fear': 351, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 362, 'fear': 351, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 362, 'fear': 352, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 362, 'fear': 353, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 363, 'fear': 353, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 364, 'fear': 353, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 364, 'fear': 354, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 365, 'fear': 354, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 366, 'fear': 354, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 367, 'fear': 354, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 367, 'fear': 355, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 368, 'fear': 355, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 368, 'fear': 356, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 368, 'fear': 357, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 369, 'fear': 357, 'joy': 29, 'sadness': 28})
# Counter({'surprise': 369, 'fear': 357, 'sadness': 29, 'joy': 29})
# Counter({'surprise': 370, 'fear': 357, 'sadness': 29, 'joy': 29})
# Counter({'surprise': 371, 'fear': 357, 'sadness': 29, 'joy': 29})
# Counter({'surprise': 371, 'fear': 358, 'sadness': 29, 'joy': 29})
# Counter({'surprise': 371, 'fear': 359, 'sadness': 29, 'joy': 29})
# Counter({'surprise': 371, 'fear': 360, 'sadness': 29, 'joy': 29})
# Counter({'surprise': 372, 'fear': 360, 'sadness': 29, 'joy': 29})
# Counter({'surprise': 373, 'fear': 360, 'sadness': 29, 'joy': 29})
# Counter({'surprise': 374, 'fear': 360, 'sadness': 29, 'joy': 29})
# Counter({'surprise': 374, 'fear': 361, 'sadness': 29, 'joy': 29})
# Counter({'surprise': 374, 'fear': 362, 'sadness': 29, 'joy': 29})
# Counter({'surprise': 374, 'fear': 362, 'joy': 30, 'sadness': 29})
# Counter({'surprise': 374, 'fear': 362, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 375, 'fear': 362, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 375, 'fear': 363, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 376, 'fear': 363, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 376, 'fear': 364, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 376, 'fear': 365, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 377, 'fear': 365, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 378, 'fear': 365, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 378, 'fear': 366, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 379, 'fear': 366, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 380, 'fear': 366, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 380, 'fear': 367, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 380, 'fear': 368, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 380, 'fear': 369, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 381, 'fear': 369, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 381, 'fear': 370, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 381, 'fear': 371, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 382, 'fear': 371, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 383, 'fear': 371, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 383, 'fear': 372, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 384, 'fear': 372, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 384, 'fear': 373, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 385, 'fear': 373, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 386, 'fear': 373, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 387, 'fear': 373, 'sadness': 30, 'joy': 30})
# Counter({'surprise': 387, 'fear': 373, 'sadness': 31, 'joy': 30})
# Counter({'surprise': 387, 'fear': 374, 'sadness': 31, 'joy': 30})
# Counter({'surprise': 387, 'fear': 374, 'sadness': 32, 'joy': 30})
# Counter({'surprise': 388, 'fear': 374, 'sadness': 32, 'joy': 30})
# Counter({'surprise': 389, 'fear': 374, 'sadness': 32, 'joy': 30})
# Counter({'surprise': 389, 'fear': 375, 'sadness': 32, 'joy': 30})
# Counter({'surprise': 389, 'fear': 376, 'sadness': 32, 'joy': 30})
# Counter({'surprise': 389, 'fear': 377, 'sadness': 32, 'joy': 30})
# Counter({'surprise': 389, 'fear': 378, 'sadness': 32, 'joy': 30})
# Counter({'surprise': 390, 'fear': 378, 'sadness': 32, 'joy': 30})
# Counter({'surprise': 391, 'fear': 378, 'sadness': 32, 'joy': 30})
# Counter({'surprise': 391, 'fear': 379, 'sadness': 32, 'joy': 30})
# Counter({'surprise': 391, 'fear': 379, 'sadness': 32, 'joy': 31})
# Counter({'surprise': 391, 'fear': 380, 'sadness': 32, 'joy': 31})
# Counter({'surprise': 392, 'fear': 380, 'sadness': 32, 'joy': 31})
# Counter({'surprise': 393, 'fear': 380, 'sadness': 32, 'joy': 31})
# Counter({'surprise': 394, 'fear': 380, 'sadness': 32, 'joy': 31})
# Counter({'surprise': 395, 'fear': 380, 'sadness': 32, 'joy': 31})
# Counter({'surprise': 395, 'fear': 381, 'sadness': 32, 'joy': 31})
# Counter({'surprise': 395, 'fear': 382, 'sadness': 32, 'joy': 31})
# Counter({'surprise': 395, 'fear': 383, 'sadness': 32, 'joy': 31})
# Counter({'surprise': 396, 'fear': 383, 'sadness': 32, 'joy': 31})
# Counter({'surprise': 397, 'fear': 383, 'sadness': 32, 'joy': 31})
# Counter({'surprise': 397, 'fear': 384, 'sadness': 32, 'joy': 31})

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
